# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings         ##############To eliminate warning popups

warnings.filterwarnings('ignore')

# %%
df2= pd.read_excel("C:\\Users\\keesi\\OneDrive\\Desktop\\Cluster(3,2).xlsx")
df2
# Out:
#                                                  Summary  overall  Sentiment  \
# 0                                       Dont waste money        1          0
# 1                                       Do not work face        2          0
# 2                                                    smh        1          0
# 3      Chalky Not Pigmented Wears easily Not Coastal ...        2          0
# 4                          Lightening BrighteningNOTHING        2          0
# ...                                                  ...      ...        ...
# 21977                      Dangerous live sunny location        1          0
# 21978                                        Bad Product        1          0
# 21979                                       Not satisfed        1          0
# 21980                                       Disappointed        1          0
# 21981                                  Did not work skin        1          0
#
# ...

# %%
df1= pd.read_excel("C:\\Users\\keesi\\OneDrive\\Desktop\\Cluster(0,1).xlsx")
df1
# Out:
#                                                 Summary  overall  Sentiment  \
# 0                                         great quality        4          1
# 1                                     Very nice palette        5          1
# 2                                            This works        5          1
# 3                                                 works        5          1
# 4                                              Did work        5          1
# ...                                                 ...      ...        ...
# 154267                                     A little dab        5          1
# 154268                     Pure organic raw shea butter        5          1
# 154269  One Pound Organic Grade A Unrefined Shea Butter        5          1
# 154270                               This stuff amazing        5          1
# 154271                                   The Real Stuff        5          1
#
# ...

# %%
df1=df1.sort_values(by='reviewTime')############Shorting the data
df1.head()
# Out:
#                               Summary  overall  Sentiment  h1          h  \
# 1392                 Gentle Hand Soap        5          1   0   0.000000
# 1361  Only shampoo husband use lately        5          1  21  44.680851
# 1366                   Good detangler        5          1   9  39.130435
# 2060                     I SO EXCITED        5          1  41  48.809524
# 1554          Sensitive Skin Sunblock        5          1  11  47.826087
#
#           reviewerID        asin  year  month  day reviewTime  Cluster
# 1392  A281NPSIMI1C2R  B0000535UX  2002      6   12 2002-06-12        0
# 1361  A281NPSIMI1C2R  B0000535UM  2002      6   16 2002-06-16        1
# 1366  A281NPSIMI1C2R  B0000535UN  2002      6   16 2002-06-16        1
# 2060   AWIF8AR75LL9L  B000065DK4  2002     11    7 2002-11-07        1
# 1554  A281NPSIMI1C2R  B0000537NH  2003      5   11 2003-05-11        1

# %%
df2=df2.sort_values(by='reviewTime')############Shorting the data
df2.head()
# Out:
#                                  Summary  overall  Sentiment  h1          h  \
# 6014                            Not good        2          0   5  27.777778
# 172                    Not great shampoo        1          0   3  30.000000
# 1157  NOT crueltyfree Amazon categorizes        2          0   4  36.363636
# 2090             No stars A major RIPOFF        1          0  80  50.000000
# 832                                Awful        1          0   1  20.000000
#
#           reviewerID        asin  year  month  day reviewTime  Cluster
# 6014   AQNDWV4YMTBZF  B001AVWSLW  2004      8   16 2004-08-16        3
# 172   A1Z54EM24Y40LL  B0000530M0  2005      4   15 2005-04-15        3
# 1157  A2YWRWSLEJRM92  B0002OCNMC  2005      6   27 2005-06-27        3
# 2090  A3PEOF0GX4EN38  B000CRGS2A  2005      7   24 2005-07-24        3
# 832   A1BHCE2409B5QF  B0001VOJWI  2005      8    8 2005-08-08        2

# %%
club=pd.read_csv("C:\\Users\\keesi\\Re_Beauty_cluster_1.csv")
club.cluster.value_counts()
# Out:
# 3    73407
# 1    60514
# 0    38909
# 2    13946
# 4    10692
# Name: cluster, dtype: int64

# %% [markdown]
# # Custeomers

# %%
va=pd.DataFrame(club.reviewerID.value_counts())
va
# Out:
#                 reviewerID
# A2V5R832QCSOMX         204
# ALNFHVS3SC4FV          190
# AKMEY1BSHSDG7          182
# A3KEZLJ59C1JVH         154
# ALQGOMOY1F5X9          149
# ...                    ...
# A3N4UKBGK8PQ2E           3
# ABH68NO7PZFWU            3
# A1NZN5STANCFO7           3
# A26X4ACKD32R2O           3
# A220E3KXVDBBD1           1
#
# [22363 rows x 1 columns]

# %%
#Premium customers
pc=va[va.reviewerID>100]
len(pc)
# Out:
# 17

# %%
#Regular customers
rc=va[va.reviewerID>50]
rc2=rc[rc.reviewerID<=100]
len(rc2)
# Out:
# 135

# %%
#Seasonal customers
sc=va[va.reviewerID<=50]
len(sc)
# Out:
# 22211

# %%
#Total customers
len(va)
# Out:
# 22363

# %% [markdown]
# # Sentiment based

# %%
club.head(10)
# Out:
#    Unnamed: 0                                            summary  overall  \
# 0           0  dont wast moneyveri oili creami expect order t...        1
# 1           1  ok palettethi palett decent price look differ ...        3
# 2           2  great qualityth textur conceal pallet fantast ...        4
# 3           3  work facei realli cant tell exactli thing powd...        2
# 4           4  okayit littl smaller expect okay last long tim...        3
# 5           5  nice palettei happi get palett wish offer subs...        5
# 6           6  smhpleas dont rachett palett size like pictur ...        1
# 7           7  chalki pigment wear easili coastal scent dupec...        2
# 8           8  lighten brighteningnothingdid noth sting put u...        2
# 9           9  alrighti bought product get rid dark spot face...        3
#
#    Sentiment          h      reviewerID        asin  year  month  day  \
# 0          0  42.857143  A1YJEY40YUW4SE  7806397051  2014      1   30
# ...

# %%
S0=club[club.Sentiment==0]
S0.asin.value_counts()
# Out:
# B007RTR9G0    77
# B007RTR9DS    70
# B004Z40048    65
# B0068Y6CA4    58
# B007BLN17K    53
#               ..
# B00AJG8JOY     1
# B002CSOYIC     1
# B000GCTAI0     1
# B007DGUREI     1
# B00AH4THVM     1
# Name: asin, Length: 8177, dtype: int64

# %%
S1=club[club.Sentiment==1]
S1.asin.value_counts()
# Out:
# B004OHQR1Q    406
# B0043OYFKU    364
# B000ZMBSPE    352
# B0069FDR96    337
# B00150LT40    310
#              ...
# B0047F9820      1
# B002T3SRRE      1
# B000BRYMKG      1
# B000CRGS2A      1
# B004C4N4TE      1
# Name: asin, Length: 12098, dtype: int64

# %% [markdown]
# # Cluster: Based

# %%
c1=club[club.cluster==1]
c1.asin.value_counts()
# Out:
# B000ZMBSPE    192
# B0043OYFKU    132
# B000AO2NXS    112
# B004D24818    111
# B002QI1E9K    111
#              ...
# B004L18FY2      1
# B003Y5XIT8      1
# B000AA2XQ4      1
# B00H416L6U      1
# B003AYCGGY      1
# Name: asin, Length: 11247, dtype: int64

# %%
c1.head()
# Out:
#     Unnamed: 0                                            summary  overall  \
# 1            1  ok palettethi palett decent price look differ ...        3
# 5            5  nice palettei happi get palett wish offer subs...        5
# 16          16  work mei order cream along soap actual work fi...        5
# 17          17  excellentgood product use littl bit spot next ...        4
# 19          19  love smell thisi havent big fan prada fragranc...        5
#
#     Sentiment          h      reviewerID        asin  year  month  day  \
# 1           1  50.000000   A60XNB876KYML  7806397051  2014      4   18
# 5           1  33.333333  A3BTN14HIZET6Z  7806397051  2013      4   15
# 16          1  33.333333   A6F8KH0J1AVYA  9759091062  2013      9   14
# 17          1  33.333333   AXPKZA7UZXKTT  9759091062  2013     10   18
# 19          1  50.000000  A1QV5IH6HDRN0L  9788072216  2011      9   19
#
#     reviewTime        Po  cluster
# 1   18-04-2014  0.277778        1
# ...

# %%
c4=club[club.cluster==4]
kk=c4.asin.value_counts()
kk.head(6)
# Out:
# B007RTR9DS    42
# B007RTR9G0    41
# B004D24818    31
# B000VPPUEA    27
# B003MJ7Z0O    23
# B003P904EA    22
# Name: asin, dtype: int64

# %%
c0.asin.value_counts()
# Out:
# B0069FDR96    123
# B003V265QW    109
# B009FKNGGQ    107
# B007BLN17K    104
# B0063A432W    102
#              ...
# B000U01WJ8      1
# B0086JQBAA      1
# B005TKVM2G      1
# B003I5XHHM      1
# B0000530LO      1
# Name: asin, Length: 9021, dtype: int64

# %% [markdown]
# # Top positive review

# %%
#Top8 in Review count
RCPL=["B004OHQR1Q","B0043OYFKU","B000ZMBSPE","B0069FDR96","B00150LT40","B000142FVW","B008U1Q4DI","B006L1DNWY"]

# %%
RCP=pd.DataFrame()
RCP=club[club['asin'].isin(RCPL)]
RCP
# Out:
#                          summary  overall  Sentiment  h1     h  \
# 5184    color differ usual choic        4          0   0   0.0
# 5185               fantast color        5          1   0   0.0
# 5186                 perfect red        5          1   0   0.0
# 5187                    rock red        5          1   1  50.0
# 5188                         hot        5          1   0   0.0
# ...                          ...      ...        ...  ..   ...
# 157369                 great buy        5          1   0   0.0
# 157370                      love        5          1   0   0.0
# 157371  much better store bought        4          1   0   0.0
# 157372    great product must buy        4          1   0   0.0
# 157373               realli cool        5          1   0   0.0
#
#             reviewerID        asin  year  month  day  reviewTime    Po  Po.1  \
# 5184    A1PJV3AXDAG2G7  B000142FVW  2012      9    9  09-09-2012 -0.25 -0.25
# ...

# %%
RCP.asin.value_counts()
# Out:
# B004OHQR1Q    431
# B0043OYFKU    402
# B0069FDR96    391
# B000ZMBSPE    389
# B00150LT40    328
# B006L1DNWY    320
# B008U1Q4DI    308
# B000142FVW    301
# Name: asin, dtype: int64

# %%
RCP_1=RCP[RCP.asin=='B004OHQR1Q']
RCP_1s=RCP_1['summary']

# %%
RCP_2=RCP[RCP.asin=='B0043OYFKU']
#RCP_2s=RCP_2['Summary']

# %%
RCP_3=RCP[RCP.asin=='B000ZMBSPE']
#RCP_3s=RCP_3['Summary']

# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#! pip install wordcloud
from wordcloud import WordCloud

# %%
RCP_1.isnull().sum()
RCP_1.dropna(inplace = True)
#Creating the text variable
sum1=RCP_1['summary']
text = " ".join(cat.split()[0] for cat in RCP_1['summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()

# %%
RCP_2.isnull().sum()
RCP_2.dropna(inplace = True)
sum2=RCP_2['summary']
text = " ".join(cat.split()[0] for cat in RCP_2['summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()

# %%
RCP_3.isnull().sum()
RCP_3.dropna(inplace = True)
sum3=RCP_3['summary']
text = " ".join(cat.split()[0] for cat in RCP_3['summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()

# %% [markdown]
# # Negative Review

# %%
RCL1=["B00A51LI10","B003P904EA","B007BLN17K","B0068Y6CA4","B004Z40048","B007RTR9DS","B007RTR9G0"]

# %%
RCL=pd.DataFrame()
RCL=club[club['asin'].isin(RCL1)]
RCL
# Out:
#                                               summary  overall  Sentiment  h1  \
# 92568                                    quick growth        5          1   0
# 92569                   add beauti routin youll happi        5          1   1
# 92570                                            work        5          1   0
# 92571                                     realli work        5          1   0
# 92572                           worthwhil sensit skin        3          1   2
# ...                                               ...      ...        ...  ..
# 148967                                     hair greas        5          1   0
# 148968  intend afroamerican hair caucasian hair still        3          1   0
# 148969                       non greasi light formula        4          1   0
# 148970                               dapper dan pomad        2          1   2
# 148971                  thick oil littl strong perfum        4          1   0
#
# ...

# %%
RCL.asin.value_counts()
# Out:
# B007RTR9G0    72
# B007RTR9DS    66
# B004Z40048    61
# B0068Y6CA4    54
# B007BLN17K    47
# B003P904EA    45
# Name: asin, dtype: int64

# %%
RCL_1=RCL[RCL.asin=='B007RTR9G0']
RCL_2=RCL[RCL.asin=='B007RTR9DS']
RCL_3=RCL[RCL.asin=='B004Z40048']

# %%
RCL_1.isnull().sum()
RCL_1.dropna(inplace = True)
#Creating the text variable
sum4=RCL_1['Summary']
text = " ".join(cat.split()[0] for cat in RCL_1['Summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()

# %%
RCL_2.isnull().sum()
RCL_2.dropna(inplace = True)
#Creating the text variable
sum5=RCL_2['Summary']
text = " ".join(cat.split()[0] for cat in RCL_1['Summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()

# %%
RCL_3.isnull().sum()
RCL_3.dropna(inplace = True)
#Creating the text variable
sum6=RCL_3['Summary']
text = " ".join(cat.split()[0] for cat in RCL_3['Summary'])
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("Overall commends")
plt.show()
